# %% [markdown]
# ## Loading Dependencies

# %%
# pandas allows for data manipulation
import pandas as pd

# %%
# These are simple classes used to make the script easier to read
import sys
sys.path.append('./')
from classes.data_wrangler import Data_Wrangler

# %% [markdown]
# ## Reading in and Restructuring the Data

# %%
# Defining the location of the data
data_dir: str = './data/fda_investigations_data.json'

# Initializing the Data_Wrangler class to manipulate the data
fda_wrangler: Data_Wrangler = Data_Wrangler(path = data_dir)
fda_wrangler.metadata()
fda_wrangler.unpack_data()
# Out:
# Please unpack the data before trying to read the metadata.

# %%
# Using the metadata to understand the data
fda_wrangler.metadata()
# Out:
# The attributes of the unnested data include:
# structure
# keys
# tables
# num_entires
# scraped_data
#
# The scraped data is structured as a dictionary
# (dict[str, pd.DataFrame]) with 7 entries. Each
# entry key is a table name as a string and each
# value is the table data as a pd.DataFrame.
#
# Keys:
# Active Investigations
# Closed Investigations 2025
# Closed Investigations 2024
# Closed Investigations 2023
# Closed Investigations 2022
# Closed Investigations 2021
# Closed Investigations 2020
#
# Number of entries: 7
#
# Here is the first table:
# Columns:
# DatePosted
# Reference#
# PathogenorCause ofIllness
# Product(s)Linked toIllnesses(if any)
# TotalCaseCount
# InvestigationStatus
# Outbreak/EventStatus
# RecallInitiated
# FDATracebackInitiated
# FDAInspectionInitiated
# FDASamplingInitiated
#
#    DatePosted Reference#                          PathogenorCause ofIllness  \
# 0   11/8/2025       1350  Clostridium botulinum (Link: https://www.cdc.g...
# 1  10/16/2025       1345  SalmonellaRichmond (Link: https://www.fda.gov/...
# 2   9/17/2025       1339  SalmonellaLomalinda (Link: https://www.fda.gov...
# 3   9/17/2025       1334  Listeriamonocytogenes (Link: https://www.fda.g...
# 4    9/4/2025       1309  Listeriamonocytogenes (Link: https://www.fda.g...
#
#   Product(s)Linked toIllnesses(if any)  \
# 0                       Infant Formula
# 1                  Moringa Leaf Powder
# 2                   Not Yet Identified
# 3                   Not Yet Identified
# 4                   Not Yet Identified
#
#                                       TotalCaseCount InvestigationStatus  \
# 0  See Advisory (Link: https://www.fda.gov/food/o...              Active
# 1  SeeAdvisory (Link: https://www.fda.gov/food/ou...              Active
# 2                                                 40              Active
# 3                                                  8              Active
# 4                                                 26              Active
#
#                                 Outbreak/EventStatus  \
# 0  OngoingSee Advisory (Link: https://www.fda.gov...
# 1  OngoingSee Advisory (Link: https://www.fda.gov...
# 2  EndedSeeAdvice (Link: https://www.fda.gov/food...
# 3  EndedSee Advice (Link: https://wcms-internet.f...
# 4  EndedSeeAdvice (Link: https://www.fda.gov/food...
#
#                                      RecallInitiated FDATracebackInitiated  \
# 0  See Advisory (Link: https://www.fda.gov/food/o...                     ✔
# 1  SeeAdvisory (Link: https://www.fda.gov/food/ou...                     ✔
# 2                                                                        ✔
# 3                                                                        ✔
# 4                                                                        ✔
#
#   FDAInspectionInitiated FDASamplingInitiated
# 0                      ✔                    ✔
# 1                      ✔                    ✔
# 2                      ✔                    ✔
# 3                      ✔                    ✔
# 4
